# %%
import json
import pyrebase
import re
from algoliasearch import algoliasearch
import pandas as pd

# %%
client = algoliasearch.Client("BNBURP768U", '1eabb4bce5a01bc2d44a7539c5c616c6')
index = client.init_index('teams')

# %%
config = {
  "apiKey": "AIzaSyAIxAM1DTRWL_GpgUnNHmjHGhdbirkklmA",
  "authDomain": "play-by-play-9b95e.firebaseapp.com",
  "databaseURL": "https://play-by-play-9b95e.firebaseio.com/",
  "storageBucket": "play-by-play-9b95e.appspot.com"
}

firebase = pyrebase.initialize_app(config)

email = 'admin@admin.com'
password = 'password'

# Get a reference to the auth service
auth = firebase.auth()

# Log the user in
user = auth.sign_in_with_email_and_password(email, password)

# Get a reference to the database service
db = firebase.database()

# %%
index.search('Northwestern')
# Out:
# {'exhaustiveNbHits': True,
#  'hits': [{'_highlightResult': {'conference': {'matchLevel': 'none',
#      'matchedWords': [],
#      'value': 'Southland Conference'},
#     'name': {'fullyHighlighted': False,
#      'matchLevel': 'full',
#      'matchedWords': ['northwestern'],
#      'value': '<em>Northwestern</em> State'},
#     'nickname': {'matchLevel': 'none', 'matchedWords': [], 'value': 'Demons'}},
#    'conference': 'Southland Conference',
#    'name': 'Northwestern State',
#    'nickname': 'Demons',
#    'objectID': '20317',
#    'tbc_team_id': 20317},
#   {'_highlightResult': {'conference': {'matchLevel': 'none',
#      'matchedWords': [],
#      'value': 'Big Ten Conference'},
#     'name': {'fullyHighlighted': True,
#      'matchLevel': 'full',
#      'matchedWords': ['northwestern'],
#      'value': '<em>Northwestern</em>'},
#     'nickname': {'matchLevel': 'none',
#      'matchedWords': [],
#      'value': 'Wildcats'}},
#    'conference': 'Big Ten Conference',
# ...

# %%
northwestern_players = db.child("players").order_by_child("tbc_team_id").equal_to(20317).get().val()
omaha_players = db.child("players").order_by_child("tbc_team_id").equal_to(20460).get().val()
northwestern_players
for k, v in omaha_players.items():
    print(k, v)
# Out:
# OrderedDict([('205809',
#               {'batter_handedness': 'R',
#                'first_name': 'Evan',
#                'last_name': 'Daigle',
#                'pitcher_handedness': 'R',
#                'tbc_player_id': 205809,
#                'tbc_team_id': 20317}),
#              ('204592',
#               {'batter_handedness': 'R',
#                'first_name': 'Dan',
#                'last_name': 'Hlad',
#                'pitcher_handedness': 'R',
#                'tbc_player_id': 204592,
#                'tbc_team_id': 20317}),
#              ('201102',
#               {'batter_handedness': 'R',
#                'first_name': 'Austin',
#                'last_name': 'Reich',
#                'pitcher_handedness': 'R',
#                'tbc_player_id': 201102,
#                'tbc_team_id': 20317}),
#              ('204998',
#               {'batter_handedness': 'B',
#                'first_name': 'Caleb',
#                'last_name': 'Ricca',
# ...

# %%
get_player_id_from_od_and_string("O'Laughlin", northwestern_players)
# Out:
# '213101'

# %%
result = [
{"away_starting_pitcher": "Grant Suponchick", "home_starting_pitcher": "Christie, Hank", "away_team": 20460, "home_team": 20037, "players": {"20460": {"214326": {"batter_handedness": "R", "first_name": "Ben", "last_name": "Palensky", "pitcher_handedness": "R", "tbc_player_id": 214326, "tbc_team_id": 20460}, "205918": {"batter_handedness": "R", "first_name": "Joey", "last_name": "Machado", "pitcher_handedness": "R", "tbc_player_id": 205918, "tbc_team_id": 20460}, "214337": {"batter_handedness": "L", "first_name": "Hunter", "last_name": "Hughes", "pitcher_handedness": "R", "tbc_player_id": 214337, "tbc_team_id": 20460}, "207634": {"batter_handedness": "R", "first_name": "Payton", "last_name": "Kinney", "pitcher_handedness": "R", "tbc_player_id": 207634, "tbc_team_id": 20460}, "205739": {"batter_handedness": "R", "first_name": "Cole", "last_name": "Thibodeau", "pitcher_handedness": "R", "tbc_player_id": 205739, "tbc_team_id": 20460}, "202877": {"batter_handedness": "L", "first_name": "Henry", "last_name": "Wittren", "pitcher_handedness": "R", "tbc_player_id": 202877, "tbc_team_id": 20460}, "214331": {"batter_handedness": "L", "first_name": "Malik", "last_name": "Moore", "pitcher_handedness": "L", "tbc_player_id": 214331, "tbc_team_id": 20460}, "194755": {"batter_handedness": "R", "first_name": "Adam", "last_name": "Caniglia", "pitcher_handedness": "R", "tbc_player_id": 194755, "tbc_team_id": 20460}, "214325": {"batter_handedness": "R", "first_name": "Tommy", "last_name": "Steier", "pitcher_handedness": "R", "tbc_player_id": 214325, "tbc_team_id": 20460}, "214332": {"batter_handedness": "R", "first_name": "Tyler", "last_name": "Phillips", "pitcher_handedness": "R", "tbc_player_id": 214332, "tbc_team_id": 20460}, "214336": {"batter_handedness": "R", "first_name": "Keil", "last_name": "Krumwiede", "pitcher_handedness": "R", "tbc_player_id": 214336, "tbc_team_id": 20460}, "214335": {"batter_handedness": "R", "first_name": "Thomas", "last_name": "DeBonville", "pitcher_handedness": "R", "tbc_player_id": 214335, "tbc_team_id": 20460}, "214333": {"batter_handedness": "R", "first_name": "Tyler", "last_name": "Daugherty", "pitcher_handedness": "R", "tbc_player_id": 214333, "tbc_team_id": 20460}, "204638": {"batter_handedness": "L", "first_name": "Adam", "last_name": "Rellihan", "pitcher_handedness": "R", "tbc_player_id": 204638, "tbc_team_id": 20460}, "202879": {"batter_handedness": "R", "first_name": "Jack", "last_name": "Kalina", "pitcher_handedness": "R", "tbc_player_id": 202879, "tbc_team_id": 20460}, "205310": {"batter_handedness": "R", "first_name": "Parker", "last_name": "Smejkal", "pitcher_handedness": "R", "tbc_player_id": 205310, "tbc_team_id": 20460}, "214329": {"batter_handedness": "L", "first_name": "Andrew", "last_name": "Brighton", "pitcher_handedness": "L", "tbc_player_id": 214329, "tbc_team_id": 20460}, "214330": {"batter_handedness": "L", "first_name": "Jake", "last_name": "Pennington", "pitcher_handedness": "R", "tbc_player_id": 214330, "tbc_team_id": 20460}, "202884": {"batter_handedness": "R", "first_name": "Josh", "last_name": "Scribner", "pitcher_handedness": "R", "tbc_player_id": 202884, "tbc_team_id": 20460}, "205488": {"batter_handedness": "L", "first_name": "Cam", "last_name": "Fowler", "pitcher_handedness": "L", "tbc_player_id": 205488, "tbc_team_id": 20460}, "214328": {"batter_handedness": "R", "first_name": "Max", "last_name": "Gamm", "pitcher_handedness": "R", "tbc_player_id": 214328, "tbc_team_id": 20460}, "206840": {"batter_handedness": "R", "first_name": "James", "last_name": "Smith", "pitcher_handedness": "R", "tbc_player_id": 206840, "tbc_team_id": 20460}, "214334": {"batter_handedness": "L", "first_name": "Spencer", "last_name": "Koelewyn", "pitcher_handedness": "L", "tbc_player_id": 214334, "tbc_team_id": 20460}, "214327": {"batter_handedness": "R", "first_name": "Braden", "last_name": "Rogers", "pitcher_handedness": "R", "tbc_player_id": 214327, "tbc_team_id": 20460}, "202873": {"batter_handedness": "R", "first_name": "Calvin", "last_name": "Hehnke", "pitcher_handedness": "R", "tbc_player_id": 202873, "tbc_team_id": 20460}, "204867": {"batter_handedness": "L", "first_name": "Nick", "last_name": "Drahozal", "pitcher_handedness": "L", "tbc_player_id": 204867, "tbc_team_id": 20460}, "202876": {"batter_handedness": "R", "first_name": "Grant", "last_name": "Suponchick", "pitcher_handedness": "R", "tbc_player_id": 202876, "tbc_team_id": 20460}}, "20037": {"213100": {"batter_handedness": "R", "first_name": "Anthony", "last_name": "Alepra", "pitcher_handedness": "R", "tbc_player_id": 213100, "tbc_team_id": 20037}, "213094": {"batter_handedness": "U", "first_name": "David", "last_name": "Dunn", "pitcher_handedness": "U", "tbc_player_id": 213094, "tbc_team_id": 20037}, "195057": {"batter_handedness": "L", "first_name": "Richard", "last_name": "Fordon", "pitcher_handedness": "L", "tbc_player_id": 195057, "tbc_team_id": 20037}, "213096": {"batter_handedness": "L", "first_name": "Jack", "last_name": "Pagliarini", "pitcher_handedness": "L", "tbc_player_id": 213096, "tbc_team_id": 20037}, "204249": {"batter_handedness": "R", "first_name": "Leo", "last_name": "Kaplan", "pitcher_handedness": "R", "tbc_player_id": 204249, "tbc_team_id": 20037}, "205672": {"batter_handedness": "L", "first_name": "Alex", "last_name": "Erro", "pitcher_handedness": "R", "tbc_player_id": 205672, "tbc_team_id": 20037}, "206118": {"batter_handedness": "L", "first_name": "Matt", "last_name": "Gannon", "pitcher_handedness": "L", "tbc_player_id": 206118, "tbc_team_id": 20037}, "201093": {"batter_handedness": "R", "first_name": "Tyler", "last_name": "Lass", "pitcher_handedness": "R", "tbc_player_id": 201093, "tbc_team_id": 20037}, "206011": {"batter_handedness": "R", "first_name": "Kyle", "last_name": "Burnett", "pitcher_handedness": "R", "tbc_player_id": 206011, "tbc_team_id": 20037}, "213099": {"batter_handedness": "R", "first_name": "Charlie", "last_name": "Bourbon", "pitcher_handedness": "R", "tbc_player_id": 213099, "tbc_team_id": 20037}, "195049": {"batter_handedness": "R", "first_name": "Tommy", "last_name": "Bordignon", "pitcher_handedness": "R", "tbc_player_id": 195049, "tbc_team_id": 20037}, "213095": {"batter_handedness": "L", "first_name": "Quinn", "last_name": "Lavelle", "pitcher_handedness": "L", "tbc_player_id": 213095, "tbc_team_id": 20037}, "207874": {"batter_handedness": "U", "first_name": "Charlie", "last_name": "Maxwell", "pitcher_handedness": "U", "tbc_player_id": 207874, "tbc_team_id": 20037}, "213098": {"batter_handedness": "L", "first_name": "Ryan", "last_name": "Bader", "pitcher_handedness": "L", "tbc_player_id": 213098, "tbc_team_id": 20037}, "201092": {"batter_handedness": "R", "first_name": "Danny", "last_name": "Katz", "pitcher_handedness": "R", "tbc_player_id": 201092, "tbc_team_id": 20037}, "206193": {"batter_handedness": "R", "first_name": "Nick", "last_name": "Paciorek", "pitcher_handedness": "R", "tbc_player_id": 206193, "tbc_team_id": 20037}, "195056": {"batter_handedness": "R", "first_name": "Jack", "last_name": "Claeys", "pitcher_handedness": "R", "tbc_player_id": 195056, "tbc_team_id": 20037}, "205591": {"batter_handedness": "L", "first_name": "Sam", "last_name": "Lawrence", "pitcher_handedness": "L", "tbc_player_id": 205591, "tbc_team_id": 20037}, "201089": {"batter_handedness": "U", "first_name": "Jack", "last_name": "Dunn", "pitcher_handedness": "U", "tbc_player_id": 201089, "tbc_team_id": 20037}, "201097": {"batter_handedness": "U", "first_name": "Mat", "last_name": "Jones", "pitcher_handedness": "U", "tbc_player_id": 201097, "tbc_team_id": 20037}, "205977": {"batter_handedness": "R", "first_name": "Josh", "last_name": "Levy", "pitcher_handedness": "R", "tbc_player_id": 205977, "tbc_team_id": 20037}, "206186": {"batter_handedness": "R", "first_name": "Nick", "last_name": "Cauley", "pitcher_handedness": "R", "tbc_player_id": 206186, "tbc_team_id": 20037}, "201091": {"batter_handedness": "U", "first_name": "Ben", "last_name": "Dickey", "pitcher_handedness": "U", "tbc_player_id": 201091, "tbc_team_id": 20037}, "201095": {"batter_handedness": "U", "first_name": "Willie", "last_name": "Bourbon", "pitcher_handedness": "U", "tbc_player_id": 201095, "tbc_team_id": 20037}, "213097": {"batter_handedness": "U", "first_name": "Jack", "last_name": "Kelly", "pitcher_handedness": "U", "tbc_player_id": 213097, "tbc_team_id": 20037}, "195053": {"batter_handedness": "R", "first_name": "J.R.", "last_name": "Reimer", "pitcher_handedness": "R", "tbc_player_id": 195053, "tbc_team_id": 20037}, "195052": {"batter_handedness": "R", "first_name": "Connor", "last_name": "Lind", "pitcher_handedness": "R", "tbc_player_id": 195052, "tbc_team_id": 20037}, "213101": {"batter_handedness": "U", "first_name": "Casey", "last_name": "O'Laughlin", "pitcher_handedness": "U", "tbc_player_id": 213101, "tbc_team_id": 20037}, "205826": {"batter_handedness": "R", "first_name": "Hank", "last_name": "Christie", "pitcher_handedness": "R", "tbc_player_id": 205826, "tbc_team_id": 20037}}}},
{"offense_team": 20460, "play": "Thibodeau,C singled to center field."},
{"offense_team": 20460, "play": "Thibodeau,C stole second."},
{"offense_team": 20460, "play": "Hughes,H struck out looking."},
{"offense_team": 20460, "play": "Krumwiede,K grounded out to ss."},
{"offense_team": 20460, "play": "Rogers,B grounded out to p."},
{"offense_team": 20037, "play": "Dickey grounded out to p."},
{"offense_team": 20037, "play": "Dunn, J. singled to third base."},
{"offense_team": 20037, "play": "Erro singled to right center; Dunn, J. advanced to third."},
{"offense_team": 20037, "play": "Erro stole second; Dunn, J. stole home."},
{"offense_team": 20037, "play": "Claeys struck out swinging, out at first c to 1b; Erro advanced to third."},
{"offense_team": 20037, "play": "Lind struck out looking."},
{"offense_team": 20460, "play": "Palensky,B struck out swinging."},
{"offense_team": 20460, "play": "Caniglia,A flied out to rf."},
{"offense_team": 20460, "play": "Smejkal,P flied out to rf."},
{"offense_team": 20037, "play": "Dunn, D. grounded out to 3b."},
{"offense_team": 20037, "play": "Maxwell flied out to cf."},
{"offense_team": 20037, "play": "Kelly grounded out to ss."},
{"offense_team": 20460, "play": "Daugherty,T singled up the middle."},
{"offense_team": 20460, "play": "Gamm,M grounded out to p, bunt; Daugherty,T advanced to second."},
{"offense_team": 20460, "play": "Thibodeau,C singled up the middle, RBI; Daugherty,T scored."},
{"offense_team": 20460, "play": "Hughes,H singled through the right side; Thibodeau,C advanced to second."},
{"offense_team": 20460, "play": "Hughes,H advanced to second on a passed ball; Thibodeau,C advanced to third on a passed ball."},
{"offense_team": 20460, "play": "Krumwiede,K tripled to right center, 2 RBI; Hughes,H scored; Thibodeau,C scored."},
{"offense_team": 20460, "play": "Rogers,B grounded out to 1b unassisted."},
{"offense_team": 20460, "play": "Palensky,B doubled to center field, RBI; Krumwiede,K scored."},
{"offense_team": 20460, "play": "Caniglia,A lined out to cf."},
{"offense_team": 20037, "play": "Bourbon tripled to right center."},
{"offense_team": 20037, "play": "Dickey grounded out to ss, RBI; Bourbon scored."},
{"offense_team": 20037, "play": "Dunn, J. singled to right field."},
{"offense_team": 20037, "play": "Erro hit by pitch; Dunn, J. advanced to second."},
{"offense_team": 20037, "play": "Claeys reached on a fielder's choice; Erro advanced to second; Dunn, J. out at third ss to 3b."},
{"offense_team": 20037, "play": "Lind walked; Claeys advanced to second; Erro advanced to third."},
{"offense_team": 20037, "play": "Dunn, D. flied out to rf."},
{"offense_team": 20460, "play": "Smejkal,P singled to third base."},
{"offense_team": 20460, "play": "Daugherty,T hit by pitch; Smejkal,P advanced to second."},
{"offense_team": 20460, "play": "Gamm,M reached on a fielder's choice; Daugherty,T out at second 3b to 2b; Smejkal,P advanced to third."},
{"offense_team": 20460, "play": "Bordignon to p for Christie."},
{"offense_team": 20460, "play": "Thibodeau,C singled to left field, advanced to second on the throw, RBI; Gamm,M advanced to third; Smejkal,P scored."},
{"offense_team": 20460, "play": "Hughes,H reached on an error by ss; Thibodeau,C scored, unearned; Gamm,M scored."},
{"offense_team": 20460, "play": "Krumwiede,K grounded out to 3b; Hughes,H advanced to second."},
{"offense_team": 20460, "play": "Rogers,B tripled down the rf line, RBI; Hughes,H scored, unearned."},
{"offense_team": 20460, "play": "Palensky,B struck out looking."},
{"offense_team": 20037, "play": "Maxwell flied out to lf."},
{"offense_team": 20037, "play": "Kelly popped up to ss."},
{"offense_team": 20037, "play": "Bourbon grounded out to 2b."},
{"offense_team": 20460, "play": "Caniglia,A grounded out to ss."},
{"offense_team": 20460, "play": "Smejkal,P singled through the left side."},
{"offense_team": 20460, "play": "Daugherty,T struck out swinging."},
{"offense_team": 20460, "play": "Gamm,M reached on a fielder's choice; Smejkal,P out at second 2b to ss."},
{"offense_team": 20037, "play": "Dickey singled to center field."},
{"offense_team": 20037, "play": "Dunn, J. flied out to rf."},
{"offense_team": 20037, "play": "Erro flied out to cf."},
{"offense_team": 20037, "play": "Dickey out at second c to ss, caught stealing."},
{"offense_team": 20460, "play": "Thibodeau,C walked."},
{"offense_team": 20460, "play": "Hughes,H grounded into double play 2b to ss to 1b; Thibodeau,C out on the play."},
{"offense_team": 20460, "play": "Krumwiede,K singled to center field."},
{"offense_team": 20460, "play": "Krumwiede,K advanced to second on a wild pitch."},
{"offense_team": 20460, "play": "Rogers,B walked."},
{"offense_team": 20460, "play": "Palensky,B struck out looking."},
{"offense_team": 20037, "play": "Claeys singled to shortstop."},
{"offense_team": 20037, "play": "Lind grounded out to 2b; Claeys advanced to second."},
{"offense_team": 20037, "play": "Dunn, D. singled to shortstop; Claeys advanced to third."},
{"offense_team": 20037, "play": "Maxwell hit by pitch; Dunn, D. advanced to second."},
{"offense_team": 20037, "play": "Moore,M to p for Suponchick,G."},
{"offense_team": 20037, "play": "Kelly walked, RBI; Maxwell advanced to second; Dunn, D. advanced to third; Claeys scored."},
{"offense_team": 20037, "play": "Bourbon grounded out to ss, RBI; Kelly advanced to second; Maxwell advanced to third; Dunn, D. scored."},
{"offense_team": 20037, "play": "Dickey struck out swinging."},
{"offense_team": 20460, "play": "Gannon to p for Bordignon."},
{"offense_team": 20460, "play": "Caniglia,A walked."},
{"offense_team": 20460, "play": "Smejkal,P singled to right field; Caniglia,A advanced to second."},
{"offense_team": 20460, "play": "Daugherty,T singled to third base, bunt; Smejkal,P advanced to second; Caniglia,A advanced to third."},
{"offense_team": 20460, "play": "Gamm,M singled through the left side, RBI; Daugherty,T advanced to second; Smejkal,P advanced to third; Caniglia,A scored."},
{"offense_team": 20460, "play": "Thibodeau,C singled to center field, RBI; Gamm,M advanced to second; Daugherty,T advanced to third; Smejkal,P scored."},
{"offense_team": 20460, "play": "Lass to p for Gannon."},
{"offense_team": 20460, "play": "Hughes,H walked, RBI; Thibodeau,C advanced to second; Gamm,M advanced to third; Daugherty,T scored."},
{"offense_team": 20460, "play": "Krumwiede,K reached on a fielder's choice, RBI; Hughes,H out at second 3b to 2b; Thibodeau,C advanced to third; Gamm,M scored."},
{"offense_team": 20460, "play": "Rogers,B walked; Krumwiede,K advanced to second."},
{"offense_team": 20460, "play": "Palensky,B singled to center field, RBI; Rogers,B advanced to second; Krumwiede,K advanced to third; Thibodeau,C scored."},
{"offense_team": 20460, "play": "Caniglia,A singled to left field, RBI; Palensky,B advanced to second; Rogers,B advanced to third; Krumwiede,K scored."},
{"offense_team": 20460, "play": "Smejkal,P popped up to rf."},
{"offense_team": 20460, "play": "Daugherty,T flied out to cf."},
{"offense_team": 20037, "play": "Dunn, J. struck out looking."},
{"offense_team": 20037, "play": "Erro walked."},
{"offense_team": 20037, "play": "Claeys struck out looking."},
{"offense_team": 20037, "play": "Erro stole second."},
{"offense_team": 20037, "play": "Erro stole third."},
{"offense_team": 20037, "play": "Lind struck out swinging."},
{"offense_team": 20460, "play": "No play."},
{"offense_team": 20460, "play": "O'Laughlin to lf for Maxwell."},
{"offense_team": 20460, "play": "No play."},
{"offense_team": 20460, "play": "Gamm,M lined out to cf."},
{"offense_team": 20460, "play": "Thibodeau,C walked."},
{"offense_team": 20460, "play": "Hughes,H grounded into double play p to ss to 1b; Thibodeau,C out on the play."},
{"offense_team": 20037, "play": "Dunn, D. tripled to right center."},
{"offense_team": 20037, "play": "O'Laughlin singled through the right side, RBI; Dunn, D. scored."},
{"offense_team": 20037, "play": "Kelly lined out to rf."},
{"offense_team": 20037, "play": "Bourbon struck out swinging."},
{"offense_team": 20037, "play": "Dickey doubled down the rf line; O'Laughlin advanced to third."},
{"offense_team": 20037, "play": "Dunn, J. singled to left field, 2 RBI; Dickey scored; O'Laughlin scored."},
{"offense_team": 20037, "play": "Dunn, J. stole second."},
{"offense_team": 20037, "play": "Erro reached on a throwing error by ss; Dunn, J. advanced to third."},
{"offense_team": 20037, "play": "Jones to c for Claeys."},
{"offense_team": 20037, "play": "Dunn, J. scored on the throw, unearned."},
{"offense_team": 20037, "play": "Jones walked; Erro advanced to second."},
{"offense_team": 20037, "play": "Lind struck out swinging."},
{"offense_team": 20460, "play": "Krumwiede,K singled to center field."},
{"offense_team": 20460, "play": "Rogers,B grounded into double play 2b to ss to 1b; Krumwiede,K out on the play."},
{"offense_team": 20460, "play": "Palensky,B flied out to rf."},
{"offense_team": 20037, "play": "Steier,T to p for Moore,M."},
{"offense_team": 20037, "play": "Dunn, D. flied out to cf."},
{"offense_team": 20037, "play": "O'Laughlin grounded out to ss."},
{"offense_team": 20037, "play": "Kelly grounded out to 2b."}
]

def get_player_id_from_od(first_name, last_name, od):
    pattern = re.compile(r'' + first_name)
    for player_id, v in od.items():
        if v['last_name'] == last_name:
            if first_name:
                match = re.match(pattern, v['first_name'])
                if bool(match):
                    return player_id
            else:
                return player_id
    raise Exception('Player Not Found')
    
def get_player_id_from_od_and_string(s, od):
    name_dict = get_first_and_last_name(s)
    return get_player_id_from_od(
        name_dict['first_name'],
        name_dict['last_name'],
        od
    )

def get_defense_team_from_info(offense_team, info):
    if offense_team == info['away_team']:
        return info['home_team']
    elif offense_team == info['home_team']:
        return info['away_team']
    raise Exception('offense_team is not away or home team')
    
def get_first_and_last_name(s):
    d = {}
    if ' ' in s and ',' in s and '.' in s:
        # Dunn, J.
        pattern = re.compile(r"([\w']+), ((?<= )[\w']+)")
        match = re.match(pattern, s)
        if bool(match) and len(match.groups()) == 2:
            d['first_name'] = match.group(2)
            d['last_name'] = match.group(1)
    elif ' ' in s and ',' in s:
        # O'Laughlin, Casey
        pattern = re.compile(r"([\w']+), ((?<= )[\w']+)")
        match = re.match(pattern, s)
        if bool(match) and len(match.groups()) == 2:
            d['first_name'] = match.group(2)
            d['last_name'] = match.group(1)
    
    elif ' ' in s:
        # Grant Suponchick
        pattern = re.compile(r"([\w'.]+) ([\w']+)")
        match = re.match(pattern, s)
        if bool(match) and len(match.groups()) == 2:
            d['first_name'] = match.group(1)
            d['last_name'] = match.group(2)
    elif ',' in s:
        # Thibodeau,C
        pattern = re.compile(r"([\w']+),([\w']+)")
        match = re.match(pattern, s)
        if bool(match) and len(match.groups()) == 2:
            d['first_name'] = match.group(2)
            d['last_name'] = match.group(1)
    else:
        d['first_name'] = ''
        d['last_name'] = s
    return d

pbp = result
info = pbp[0]
d = list(filter(lambda a: a['play'] != 'No play.', pbp[1:]))

info['away_starting_pitcher'] = get_player_id_from_od_and_string(info['away_starting_pitcher'], info['players'][str(info['away_team'])])
info['home_starting_pitcher'] = get_player_id_from_od_and_string(info['home_starting_pitcher'], info['players'][str(info['home_team'])])
    
pitcher_against = {
    info['away_team']: info['home_starting_pitcher'],
    info['home_team']: info['away_starting_pitcher']
}

for play in d:
    # add pitcher col
    play['pitcher'] = pitcher_against[play['offense_team']]

    # update pitcher_against
    pattern = r"(\w+'?\w+\,[A-Z]|\w+'?\w+,\s[A-Z].|\w+'?\w+)(?= to p for)"
    match = re.search(pattern, play['play'])
    if bool(match):
        defense_team = get_defense_team_from_info(play['offense_team'], info)
        pitcher_against[play['offense_team']] = get_player_id_from_od_and_string(match.group(0), info['players'][str(defense_team)])
        continue
        
    # catch substitutions
    pattern = r"(\w+'?\w+\,[A-Z]|\w+'?\w+,\s[A-Z].|\w+'?\w+)(?= to (1b|2b|3b|ss|lf|cf|rf) for)"
    match = re.search(pattern, play['play'])
    if bool(match):
        continue
    
    # add name col
    pattern = r"(\w+'?\w+\,[A-Z]|\w+'?\w+,\s[A-Z].|\w+'?\w+)"
    match = re.match(pattern, play['play'])
    if bool(match):
        play['name'] = get_player_id_from_od_and_string(match.group(0), info['players'][str(play['offense_team'])])
    else:
        raise Exception('No Name')

    # add pa_result col
        # stole
    pattern = r"(stole)"
    match = re.search(pattern, play['play'])
    if bool(match):
        play['pa_result'] = match.group(0)

        # struck out looking, struck out swinging, walked, hit by pitch
    pattern = r"(struck out looking|struck out swinging|walked|hit by pitch)"
    match = re.search(pattern, play['play'])

    if bool(match):
        play['pa_result'] = match.group(0)

        # ground, lined, flied ... and batted_ball_location col
    pattern = r"(grounded|lined|flied|popped|reached|singled|doubled|tripled|homered).*(p|1b|2b|3b|ss|lf|cf|rf|left field|center field|right field|first base|second base|third base|left center|right center|left side|middle|right side)\b"
    match = re.search(pattern, play['play'])

    if bool(match):
        play['pa_result'] = match.group(1)
        play['batted_ball_location'] = match.group(2)

    # batted_ball_location for double play
    pattern = r"(grounded|lined|flied|popped|reached|singled|doubled|tripled|homered).*(?<!to )(p|1b|2b|3b|ss|lf|cf|rf)\b"
    match = re.search(pattern, play['play'])

    if bool(match):
        play['batted_ball_location'] = match.group(2)

pd.DataFrame(d)
# Out:
#     batted_ball_location    name  offense_team            pa_result pitcher  \
# 0           center field  205739         20460              singled  205826
# 1                    NaN  205739         20460                stole  205826
# 2                    NaN  214337         20460   struck out looking  205826
# 3                     ss  214336         20460             grounded  205826
# 4                      p  214327         20460             grounded  205826
# 5                      p  201091         20037             grounded  202876
# 6             third base  201089         20037              singled  202876
# 7           right center  205672         20037              singled  202876
# 8                    NaN  205672         20037                stole  202876
# 9                    NaN  195056         20037  struck out swinging  202876
# 10                   NaN  195052         20037   struck out looking  202876
# ...

# %%
pd.DataFrame([
{"offense_team": 20460, "play": "Thibodeau,C singled to center field.", "pitcher": "205826", "name": "205739", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20460, "play": "Thibodeau,C stole second.", "pitcher": "205826", "name": "205739", "pa_result": "SB"},
{"offense_team": 20460, "play": "Hughes,H struck out looking.", "pitcher": "205826", "name": "214337", "pa_result": "K"},
{"offense_team": 20460, "play": "Krumwiede,K grounded out to ss.", "pitcher": "205826", "name": "214336", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20460, "play": "Rogers,B grounded out to p.", "pitcher": "205826", "name": "214327", "pa_result": "G", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Dickey grounded out to p.", "pitcher": "202876", "name": "201091", "pa_result": "G", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Dunn, J. singled to third base.", "pitcher": "202876", "name": "201089", "pa_result": "1B", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Erro singled to right center; Dunn, J. advanced to third.", "pitcher": "202876", "name": "205672", "pa_result": "1B", "batted_ball_location": "RC"},
{"offense_team": 20037, "play": "Erro stole second; Dunn, J. stole home.", "pitcher": "202876", "name": "205672", "pa_result": "SB"},
{"offense_team": 20037, "play": "Claeys struck out swinging, out at first c to 1b; Erro advanced to third.", "pitcher": "202876", "name": "195056", "pa_result": "K"},
{"offense_team": 20037, "play": "Lind struck out looking.", "pitcher": "202876", "name": "195052", "pa_result": "K"},
{"offense_team": 20460, "play": "Palensky,B struck out swinging.", "pitcher": "205826", "name": "214326", "pa_result": "K"},
{"offense_team": 20037, "play": "Dickey struck out swinging (1-2 KFBS).", "pitcher": "205328", "name": "201091", "pa_result": "K"},
{"offense_team": 20460, "play": "Thibodeau,C struck out swinging.", "pitcher": "201092", "name": "205739", "pa_result": "K"},
{"offense_team": 20460, "play": "Caniglia,A flied out to rf.", "pitcher": "205826", "name": "194755", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Smejkal,P flied out to rf.", "pitcher": "205826", "name": "205310", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Dunn, D. grounded out to 3b.", "pitcher": "202876", "name": "213094", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Maxwell flied out to cf.", "pitcher": "202876", "name": "207874", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Kelly grounded out to ss.", "pitcher": "202876", "name": "213097", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20460, "play": "Daugherty,T singled up the middle.", "pitcher": "205826", "name": "214333", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Dunn, J. struck out swinging (3-2 BKSBBS).", "pitcher": "205328", "name": "201089", "pa_result": "K"},
{"offense_team": 20037, "play": "Erro struck out looking (2-2 BKBFK).", "pitcher": "205328", "name": "205672", "pa_result": "K"},
{"offense_team": 20454, "play": "Sems, B. reached on a fielding error by 1b (1-2 KBF).", "pitcher": "205826", "name": "205446", "pa_result": "E/FC", "batted_ball_location": "1B"},
{"offense_team": 20454, "play": "Cosentino grounded into double play ss to 2b to 1b (2-1 BBK); Sems, B. out on the play.", "pitcher": "205826", "name": "206843", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20454, "play": "Groshans, J. flied out to rf (0-1 K).", "pitcher": "205826", "name": "204752", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Bourbon homered to left center, RBI (3-2 KBBSB).", "pitcher": "205328", "name": "213099", "pa_result": "HR", "batted_ball_location": "LC"},
{"offense_team": 20037, "play": "Lind flied out to rf (2-0 BB).", "pitcher": "205328", "name": "195052", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Claeys reached on a fielding error by ss (2-2 SBKFB).", "pitcher": "205328", "name": "195056", "pa_result": "E/FC", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Dunn, D. singled to pitcher (0-1 F); Claeys advanced to second.", "pitcher": "205328", "name": "213094"},
{"offense_team": 20460, "play": "Hughes,H flied out to lf.", "pitcher": "201092", "name": "214337", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20460, "play": "Krumwiede,K flied out to rf.", "pitcher": "201092", "name": "214336", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Dickey walked.", "pitcher": "202873", "name": "201091", "pa_result": "BB"},
{"offense_team": 20037, "play": "Dickey stole second.", "pitcher": "202873", "name": "201091", "pa_result": "SB"},
{"offense_team": 20037, "play": "Dunn, J. struck out looking.", "pitcher": "202873", "name": "201089", "pa_result": "K"},
{"offense_team": 20037, "play": "Dickey stole third.", "pitcher": "202873", "name": "201091", "pa_result": "SB"},
{"offense_team": 20037, "play": "Erro flied out to rf, SF, RBI; Dickey scored.", "pitcher": "202873", "name": "205672", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Gamm,M grounded out to p, bunt; Daugherty,T advanced to second.", "pitcher": "205826", "name": "214328", "pa_result": "G", "batted_ball_location": "P"},
{"offense_team": 20460, "play": "Thibodeau,C singled up the middle, RBI; Daugherty,T scored.", "pitcher": "205826", "name": "205739", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20460, "play": "Hughes,H singled through the right side; Thibodeau,C advanced to second.", "pitcher": "205826", "name": "214337", "pa_result": "1B", "batted_ball_location": "RS"},
{"offense_team": 20460, "play": "Hughes,H advanced to second on a passed ball; Thibodeau,C advanced to third on a passed ball.", "pitcher": "205826", "name": "214337"},
{"offense_team": 20460, "play": "Krumwiede,K tripled to right center, 2 RBI; Hughes,H scored; Thibodeau,C scored.", "pitcher": "205826", "name": "214336", "pa_result": "3B", "batted_ball_location": "RC"},
{"offense_team": 20460, "play": "Rogers,B grounded out to 1b unassisted.", "pitcher": "205826", "name": "214327", "pa_result": "G", "batted_ball_location": "1B"},
{"offense_team": 20460, "play": "Palensky,B doubled to center field, RBI; Krumwiede,K scored.", "pitcher": "205826", "name": "214326", "pa_result": "2B", "batted_ball_location": "CF"},
{"offense_team": 20460, "play": "Caniglia,A lined out to cf.", "pitcher": "205826", "name": "194755", "pa_result": "L", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Bourbon tripled to right center.", "pitcher": "202876", "name": "213099", "pa_result": "3B", "batted_ball_location": "RC"},
{"offense_team": 20037, "play": "Dickey grounded out to ss, RBI; Bourbon scored.", "pitcher": "202876", "name": "201091", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Dunn, J. singled to right field.", "pitcher": "202876", "name": "201089", "pa_result": "1B", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Erro hit by pitch; Dunn, J. advanced to second.", "pitcher": "202876", "name": "205672", "pa_result": "HBP"},
{"offense_team": 20037, "play": "Claeys reached on a fielder's choice; Erro advanced to second; Dunn, J. out at third ss to 3b.", "pitcher": "202876", "name": "195056", "pa_result": "E/FC", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Lind walked; Claeys advanced to second; Erro advanced to third.", "pitcher": "202876", "name": "195052", "pa_result": "BB"},
{"offense_team": 20460, "play": "Thibodeau,C struck out swinging.", "pitcher": "213095", "name": "205739", "pa_result": "K"},
{"offense_team": 20037, "play": "Dickey walked (3-2 KSBFBBB).", "pitcher": "200400", "name": "201091", "pa_result": "BB"},
{"offense_team": 20037, "play": "Dickey grounded out to 3b (0-1 K).", "pitcher": "204253", "name": "201091", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Kaplan singled up the middle, advanced to second on the throw, RBI (2-0 BB); Dunn, D. advanced to second, advanced to third on the throw; Claeys scored, unearned.", "pitcher": "205328", "name": "204249", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Kaplan advanced to third on a wild pitch; Dunn, D. scored on a wild pitch, unearned.", "pitcher": "205328", "name": "204249"},
{"offense_team": 20037, "play": "Claeys flied out to rf.", "pitcher": "202873", "name": "195056", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Rogers,B grounded out to 2b.", "pitcher": "201092", "name": "214327", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Palensky,B lined out to 1b.", "pitcher": "201092", "name": "214326", "pa_result": "L", "batted_ball_location": "1B"},
{"offense_team": 20460, "play": "Scribner,J grounded out to ss.", "pitcher": "201092", "name": "202884", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Lind grounded out to ss.", "pitcher": "202873", "name": "195052", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Dunn, D. walked.", "pitcher": "202873", "name": "213094", "pa_result": "BB"},
{"offense_team": 20037, "play": "Dunn, D. stole second.", "pitcher": "202873", "name": "213094", "pa_result": "SB"},
{"offense_team": 20037, "play": "Bourbon flied out to rf, SF; Dunn, D. advanced to third.", "pitcher": "202873", "name": "213099", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Kelly reached on an error by 3b; Dunn, D. scored, unearned.", "pitcher": "202873", "name": "213097", "pa_result": "E/FC", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Dunn, D. flied out to rf.", "pitcher": "202876", "name": "213094", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Smejkal,P singled to third base.", "pitcher": "205826", "name": "205310", "pa_result": "1B", "batted_ball_location": "3B"},
{"offense_team": 20460, "play": "Daugherty,T hit by pitch; Smejkal,P advanced to second.", "pitcher": "205826", "name": "214333", "pa_result": "HBP"},
{"offense_team": 20460, "play": "Gamm,M reached on a fielder's choice; Daugherty,T out at second 3b to 2b; Smejkal,P advanced to third.", "pitcher": "205826", "name": "214328", "pa_result": "E/FC", "batted_ball_location": "3B"},
{"offense_team": 20460, "play": "Thibodeau,C singled to left field, advanced to second on the throw, RBI; Gamm,M advanced to third; Smejkal,P scored.", "pitcher": "195049", "name": "205739", "pa_result": "1B", "batted_ball_location": "LF"},
{"offense_team": 20460, "play": "Hughes,H reached on an error by ss; Thibodeau,C scored, unearned; Gamm,M scored.", "pitcher": "195049", "name": "214337", "pa_result": "E/FC", "batted_ball_location": "SS"},
{"offense_team": 20460, "play": "Krumwiede,K grounded out to 3b; Hughes,H advanced to second.", "pitcher": "195049", "name": "214336", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20460, "play": "Rogers,B tripled down the rf line, RBI; Hughes,H scored, unearned.", "pitcher": "195049", "name": "214327", "pa_result": "3B", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Rogers,B struck out swinging.", "pitcher": "213095", "name": "214327", "pa_result": "K"},
{"offense_team": 20460, "play": "Krumwiede,K walked.", "pitcher": "213095", "name": "214336", "pa_result": "BB"},
{"offense_team": 20460, "play": "Suponchick,G flied out to cf.", "pitcher": "213095", "name": "202876", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dickey singled to center field.", "pitcher": "205918", "name": "201091", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dunn, J. reached on a fielder's choice, bunt (0-0); Dickey out at second p to ss.", "pitcher": "200400", "name": "201089", "pa_result": "E/FC", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Dunn, J. out at first p to 1b, picked off.", "pitcher": "200400", "name": "201089"},
{"offense_team": 20037, "play": "Erro flied out to lf (2-2 KBSB).", "pitcher": "200400", "name": "205672", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20454, "play": "Ray, B. grounded out to ss (1-0 B).", "pitcher": "213095", "name": "215108", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20454, "play": "Cosentino flied out to cf (1-2 KBF).", "pitcher": "213095", "name": "206843", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20454, "play": "Groshans, J. homered to left field, RBI (3-1 BBBK).", "pitcher": "213095", "name": "204752", "pa_result": "HR", "batted_ball_location": "LF"},
{"offense_team": 20454, "play": "Citta, B. walked (3-1 BBBKB).", "pitcher": "213095", "name": "201464", "pa_result": "BB"},
{"offense_team": 20454, "play": "Foyle, D. flied out to cf (0-0).", "pitcher": "213095", "name": "200402", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dunn, J. flied out to rf (1-1 KB).", "pitcher": "204253", "name": "201089", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Erro grounded out to 2b (0-2 KF).", "pitcher": "204253", "name": "205672", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20454, "play": "Vosik, B. singled through the right side (1-1 BK).", "pitcher": "201092", "name": "206533", "pa_result": "1B", "batted_ball_location": "RS"},
{"offense_team": 20454, "play": "Cosentino grounded into double play ss to 1b (1-2 KBSF); Vosik, B. out on the play.", "pitcher": "201092", "name": "206843", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20454, "play": "Groshans, J. flied out to rf (1-1 KB).", "pitcher": "201092", "name": "204752", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Bourbon homered to left field, RBI (0-2 KK).", "pitcher": "204253", "name": "213099", "pa_result": "HR", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "O'Laughlin grounded out to 2b.", "pitcher": "202873", "name": "213101", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Smejkal,P struck out looking.", "pitcher": "201092", "name": "205310", "pa_result": "K"},
{"offense_team": 20460, "play": "Daugherty,T walked.", "pitcher": "201092", "name": "214333", "pa_result": "BB"},
{"offense_team": 20460, "play": "Gamm,M reached on an error by rf, advanced to second; Daugherty,T advanced to third.", "pitcher": "201092", "name": "214328", "pa_result": "E/FC", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Thibodeau,C flied out to lf, SF, RBI; Gamm,M advanced to third; Daugherty,T scored, unearned.", "pitcher": "201092", "name": "205739", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20460, "play": "Gamm,M scored on a wild pitch, unearned.", "pitcher": "201092", "name": "214328"},
{"offense_team": 20460, "play": "Hughes,H flied out to lf.", "pitcher": "201092", "name": "214337", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Dickey hit by pitch.", "pitcher": "202873", "name": "201091", "pa_result": "HBP"},
{"offense_team": 20037, "play": "Dunn, J. grounded out to 1b unassisted, SAC; Dickey advanced to second.", "pitcher": "202873", "name": "201089", "pa_result": "G", "batted_ball_location": "1B"},
{"offense_team": 20460, "play": "Palensky,B struck out looking.", "pitcher": "195049", "name": "214326", "pa_result": "K"},
{"offense_team": 20037, "play": "Maxwell flied out to lf.", "pitcher": "202876", "name": "207874", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Kelly popped up to ss.", "pitcher": "202876", "name": "213097", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Bourbon grounded out to 2b.", "pitcher": "202876", "name": "213099", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Caniglia,A grounded out to ss.", "pitcher": "195049", "name": "194755", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Dunn, J. struck out swinging.", "pitcher": "205918", "name": "201089", "pa_result": "K"},
{"offense_team": 20037, "play": "Dickey stole second.", "pitcher": "205918", "name": "201091", "pa_result": "SB"},
{"offense_team": 20037, "play": "Erro flied out to lf.", "pitcher": "205918", "name": "205672", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Claeys grounded out to 3b.", "pitcher": "205918", "name": "195056", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20460, "play": "Palensky,B grounded out to p.", "pitcher": "213095", "name": "214326", "pa_result": "G", "batted_ball_location": "P"},
{"offense_team": 20460, "play": "Caniglia,A grounded out to ss.", "pitcher": "213095", "name": "194755", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20460, "play": "Smejkal,P struck out swinging.", "pitcher": "213095", "name": "205310", "pa_result": "K"},
{"offense_team": 20037, "play": "Lind grounded out to ss.", "pitcher": "205918", "name": "195052", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Bourbon walked.", "pitcher": "205918", "name": "213099", "pa_result": "BB"},
{"offense_team": 20037, "play": "Dunn, D. hit by pitch; Bourbon advanced to second.", "pitcher": "205918", "name": "213094", "pa_result": "HBP"},
{"offense_team": 20037, "play": "Kelly flied out to lf.", "pitcher": "205918", "name": "213097", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "O'Laughlin popped up to ss.", "pitcher": "205918", "name": "213101", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20460, "play": "Daugherty,T fouled out to 1b.", "pitcher": "213095", "name": "214333"},
{"offense_team": 20460, "play": "Gamm,M singled to left field.", "pitcher": "213095", "name": "214328", "pa_result": "1B", "batted_ball_location": "LF"},
{"offense_team": 20460, "play": "Thibodeau,C singled to left field; Gamm,M advanced to second.", "pitcher": "213095", "name": "205739", "pa_result": "1B", "batted_ball_location": "LF"},
{"offense_team": 20460, "play": "Rogers,B lined out to 3b; Gamm,M out at second 3b to 2b.", "pitcher": "213095", "name": "214327", "pa_result": "L", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Dickey singled to second base.", "pitcher": "205918", "name": "201091", "pa_result": "1B", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Dunn, J. singled through the right side; Dickey advanced to third.", "pitcher": "205918", "name": "201089", "pa_result": "1B", "batted_ball_location": "RS"},
{"offense_team": 20037, "play": "Bourbon grounded out to 2b (1-2 KBK).", "pitcher": "200400", "name": "213099", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Lind singled through the right side (0-1 K).", "pitcher": "200400", "name": "195052", "pa_result": "1B", "batted_ball_location": "RS"},
{"offense_team": 20037, "play": "Dunn, D. walked (3-2 KBBSBB); Lind advanced to second.", "pitcher": "200400", "name": "213094", "pa_result": "BB"},
{"offense_team": 20037, "play": "Kaplan struck out swinging (1-2 BSSS).", "pitcher": "200400", "name": "204249", "pa_result": "K"},
{"offense_team": 20037, "play": "Maxwell fouled out to 3b (1-0 B).", "pitcher": "200400", "name": "207874"},
{"offense_team": 20454, "play": "Bakula, L. grounded out to ss (2-2 FBFBFF).", "pitcher": "213095", "name": "204817", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Lind grounded out to ss (3-2 KKBBB).", "pitcher": "204253", "name": "195052", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Claeys struck out looking (1-2 BKSK).", "pitcher": "204253", "name": "195056", "pa_result": "K"},
{"offense_team": 20037, "play": "Dunn, D. grounded out to ss (1-0 B).", "pitcher": "204253", "name": "213094", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20454, "play": "Citta, B. singled up the middle (2-1 KBB).", "pitcher": "201092", "name": "201464", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20454, "play": "Foyle, D. doubled down the rf line (0-1 K); Citta, B. advanced to third.", "pitcher": "201092", "name": "200402", "pa_result": "2B", "batted_ball_location": "RF"},
{"offense_team": 20454, "play": "Kyriacou, D. walked (3-2 BKFBBB).", "pitcher": "201092", "name": "200398", "pa_result": "BB"},
{"offense_team": 20454, "play": "Taylor, O. singled through the right side, 2 RBI (0-1 K); Kyriacou, D. advanced to third; Foyle, D. scored; Citta, B. scored.", "pitcher": "201092", "name": "188251", "pa_result": "1B", "batted_ball_location": "RS"},
{"offense_team": 20454, "play": "Sems, B. flied out to rf, SF, RBI (1-0 B); Kyriacou, D. scored.", "pitcher": "201092", "name": "205446", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Dickey advanced to third on a balk.", "pitcher": "202873", "name": "201091"},
{"offense_team": 20037, "play": "Erro out at first 1b to p, RBI; Dickey scored.", "pitcher": "202873", "name": "205672"},
{"offense_team": 20037, "play": "Claeys grounded out to 3b.", "pitcher": "202873", "name": "195056", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20460, "play": "Krumwiede,K struck out looking.", "pitcher": "201092", "name": "214336", "pa_result": "K"},
{"offense_team": 20460, "play": "Rogers,B flied out to rf.", "pitcher": "201092", "name": "214327", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Palensky,B singled to right field.", "pitcher": "201092", "name": "214326", "pa_result": "1B", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Scribner,J reached on a fielder's choice; Palensky,B out at second 2b to ss.", "pitcher": "201092", "name": "202884", "pa_result": "E/FC", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Lind struck out looking.", "pitcher": "202873", "name": "195052", "pa_result": "K"},
{"offense_team": 20037, "play": "Dunn, D. reached on an error by cf, advanced to third.", "pitcher": "202873", "name": "213094", "pa_result": "E/FC", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Bourbon homered, 2 RBI; Dunn, D. scored.", "pitcher": "202873", "name": "213099"},
{"offense_team": 20037, "play": "Kelly grounded out to p.", "pitcher": "202873", "name": "213097", "pa_result": "G", "batted_ball_location": "P"},
{"offense_team": 20460, "play": "Smejkal,P singled through the left side.", "pitcher": "195049", "name": "205310", "pa_result": "1B", "batted_ball_location": "LS"},
{"offense_team": 20460, "play": "Daugherty,T struck out swinging.", "pitcher": "195049", "name": "214333", "pa_result": "K"},
{"offense_team": 20460, "play": "Gamm,M reached on a fielder's choice; Smejkal,P out at second 2b to ss.", "pitcher": "195049", "name": "214328", "pa_result": "E/FC", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Dickey singled to center field.", "pitcher": "202876", "name": "201091", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dunn, J. flied out to rf.", "pitcher": "202876", "name": "201089", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Erro flied out to cf.", "pitcher": "202876", "name": "205672", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Erro struck out swinging; Dunn, J. stole second; Dickey out at home c to ss to c.", "pitcher": "205918", "name": "205672", "pa_result": "K"},
{"offense_team": 20037, "play": "Claeys grounded out to 2b.", "pitcher": "205918", "name": "195056", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Krumwiede,K flied out to cf.", "pitcher": "213095", "name": "214336", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20460, "play": "Suponchick,G grounded out to ss.", "pitcher": "213095", "name": "202876", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20460, "play": "Palensky,B struck out swinging.", "pitcher": "213095", "name": "214326", "pa_result": "K"},
{"offense_team": 20037, "play": "Lind walked.", "pitcher": "205918", "name": "195052", "pa_result": "BB"},
{"offense_team": 20037, "play": "Bourbon doubled to right center; Lind advanced to third.", "pitcher": "205918", "name": "213099", "pa_result": "2B", "batted_ball_location": "RC"},
{"offense_team": 20037, "play": "Dunn, D. grounded out to ss, RBI; Bourbon advanced to third; Lind scored.", "pitcher": "205918", "name": "213094", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Kelly grounded out to 1b unassisted, RBI; Bourbon scored.", "pitcher": "205918", "name": "213097", "pa_result": "G", "batted_ball_location": "1B"},
{"offense_team": 20037, "play": "O'Laughlin grounded out to 2b.", "pitcher": "205918", "name": "213101", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Caniglia,A grounded out to 2b.", "pitcher": "213095", "name": "194755", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Smejkal,P singled to right field.", "pitcher": "213095", "name": "205310", "pa_result": "1B", "batted_ball_location": "RF"},
{"offense_team": 20454, "play": "Taylor, O. grounded out to 2b (0-1 S).", "pitcher": "213095", "name": "188251", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20454, "play": "Messinger, S grounded out to ss (1-2 BFF).", "pitcher": "213095", "name": "210030", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Kelly popped up to ss (2-1 BKB).", "pitcher": "200400", "name": "213097", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Dickey struck out swinging (1-2 KBKFS).", "pitcher": "200400", "name": "201091", "pa_result": "K"},
{"offense_team": 20037, "play": "Dunn, J. doubled down the lf line (2-2 KKBB).", "pitcher": "200400", "name": "201089", "pa_result": "2B", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Erro grounded out to 2b (0-0).", "pitcher": "200400", "name": "205672", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20454, "play": "Sems, B. flied out to lf (3-2 BKBFB).", "pitcher": "213095", "name": "205446", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20454, "play": "Ray, B. struck out swinging, out at first c to 1b (0-2 KSS).", "pitcher": "213095", "name": "215108", "pa_result": "K"},
{"offense_team": 20454, "play": "Cosentino doubled to left field (1-2 KBK).", "pitcher": "213095", "name": "206843", "pa_result": "2B", "batted_ball_location": "LF"},
{"offense_team": 20454, "play": "Cosentino advanced to third on a throwing error by p, failed pickoff attempt.", "pitcher": "213095", "name": "206843"},
{"offense_team": 20454, "play": "Groshans, J. grounded out to ss (1-0 B).", "pitcher": "213095", "name": "204752", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Bourbon grounded out to 2b (2-2 BFSB).", "pitcher": "200400", "name": "213099", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20454, "play": "Zunica, M. reached on a fielder's choice (0-0); Taylor, O. out at second ss to 2b.", "pitcher": "201092", "name": "206984", "pa_result": "E/FC", "batted_ball_location": "SS"},
{"offense_team": 20454, "play": "Vosik, B. singled through the left side (1-1 KB); Zunica, M. advanced to third.", "pitcher": "201092", "name": "206533", "pa_result": "1B", "batted_ball_location": "LS"},
{"offense_team": 20454, "play": "Cosentino flied out to cf (1-2 KBF).", "pitcher": "201092", "name": "206843", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Kaplan struck out swinging, reached first on a wild pitch (1-2 SKBS).", "pitcher": "204253", "name": "204249", "pa_result": "K"},
{"offense_team": 20037, "play": "O'Laughlin grounded out to c unassisted.", "pitcher": "202873", "name": "213101"},
{"offense_team": 20460, "play": "Smejkal,P doubled to right field.", "pitcher": "201092", "name": "205310", "pa_result": "2B", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Daugherty,T flied out to cf.", "pitcher": "201092", "name": "214333", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20460, "play": "Gamm,M singled up the middle; Smejkal,P advanced to third.", "pitcher": "201092", "name": "214328", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20460, "play": "Thibodeau,C reached on an error by 1b; Gamm,M advanced to second.", "pitcher": "201092", "name": "205739", "pa_result": "E/FC", "batted_ball_location": "1B"},
{"offense_team": 20460, "play": "Hughes,H reached on a throwing error by 3b, RBI; Thibodeau,C advanced to second; Gamm,M out at third 3b unassisted; Smejkal,P scored.", "pitcher": "201092", "name": "214337", "pa_result": "E/FC", "batted_ball_location": "3B"},
{"offense_team": 20460, "play": "Krumwiede,K lined out to 2b.", "pitcher": "201092", "name": "214336", "pa_result": "L", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Dickey out at second c to ss, caught stealing.", "pitcher": "202876", "name": "201091"},
{"offense_team": 20460, "play": "Thibodeau,C walked.", "pitcher": "195049", "name": "205739", "pa_result": "BB"},
{"offense_team": 20460, "play": "Hughes,H grounded into double play 2b to ss to 1b; Thibodeau,C out on the play.", "pitcher": "195049", "name": "214337", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Krumwiede,K singled to center field.", "pitcher": "195049", "name": "214336", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20460, "play": "Krumwiede,K advanced to second on a wild pitch.", "pitcher": "195049", "name": "214336"},
{"offense_team": 20460, "play": "Rogers,B walked.", "pitcher": "195049", "name": "214327", "pa_result": "BB"},
{"offense_team": 20460, "play": "Palensky,B struck out looking.", "pitcher": "195049", "name": "214326", "pa_result": "K"},
{"offense_team": 20037, "play": "Claeys singled to shortstop.", "pitcher": "202876", "name": "195056", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Lind grounded out to 2b; Claeys advanced to second.", "pitcher": "202876", "name": "195052", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Smejkal,P stole second.", "pitcher": "213095", "name": "205310", "pa_result": "SB"},
{"offense_team": 20460, "play": "Daugherty,T fouled out to 1b.", "pitcher": "213095", "name": "214333"},
{"offense_team": 20460, "play": "Gamm,M struck out swinging.", "pitcher": "213095", "name": "214328", "pa_result": "K"},
{"offense_team": 20037, "play": "Dickey grounded out to ss.", "pitcher": "207634", "name": "201091", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Dunn, J. struck out swinging, grounded out to c unassisted.", "pitcher": "207634", "name": "201089", "pa_result": "K"},
{"offense_team": 20037, "play": "Erro walked.", "pitcher": "207634", "name": "205672", "pa_result": "BB"},
{"offense_team": 20037, "play": "Erro stole second.", "pitcher": "207634", "name": "205672", "pa_result": "SB"},
{"offense_team": 20037, "play": "Claeys struck out swinging.", "pitcher": "207634", "name": "195056", "pa_result": "K"},
{"offense_team": 20460, "play": "Thibodeau,C struck out swinging.", "pitcher": "213096", "name": "205739", "pa_result": "K"},
{"offense_team": 20460, "play": "Rogers,B grounded out to ss.", "pitcher": "213096", "name": "214327", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Lind lined out to 3b (1-1 KB).", "pitcher": "200400", "name": "195052", "pa_result": "L", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Dunn, D. grounded out to 2b (2-1 KBB).", "pitcher": "200400", "name": "213094", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20454, "play": "Citta, B. walked (3-2 KBBFBB).", "pitcher": "213095", "name": "201464", "pa_result": "BB"},
{"offense_team": 20454, "play": "Foyle, D. homered to left center, 2 RBI (1-2 KBFF); Citta, B. scored.", "pitcher": "213095", "name": "200402", "pa_result": "HR", "batted_ball_location": "LC"},
{"offense_team": 20454, "play": "Bakula, L. struck out looking (2-2 BFFBK).", "pitcher": "213095", "name": "204817", "pa_result": "K"},
{"offense_team": 20454, "play": "Taylor, O. singled through the left side (2-1 FBB).", "pitcher": "213095", "name": "188251", "pa_result": "1B", "batted_ball_location": "LS"},
{"offense_team": 20454, "play": "Messinger, S doubled down the rf line (0-0); Taylor, O. advanced to third.", "pitcher": "213095", "name": "210030", "pa_result": "2B", "batted_ball_location": "RF"},
{"offense_team": 20454, "play": "Sems, B. struck out swinging (3-2 BBKBKFS).", "pitcher": "213095", "name": "205446", "pa_result": "K"},
{"offense_team": 20454, "play": "Ray, B. flied out to rf (1-2 KKFB).", "pitcher": "213095", "name": "215108", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Kaplan struck out swinging (0-2 KSS).", "pitcher": "200400", "name": "204249", "pa_result": "K"},
{"offense_team": 20037, "play": "Dickey flied out to rf.", "pitcher": "214330", "name": "201091", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Dunn, J. reached on an error by ss.", "pitcher": "214330", "name": "201089", "pa_result": "E/FC", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Erro flied out to cf.", "pitcher": "214330", "name": "205672", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Claeys flied out to cf.", "pitcher": "214330", "name": "195056", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20460, "play": "Rogers,B singled through the right side.", "pitcher": "213098", "name": "214327", "pa_result": "1B", "batted_ball_location": "RS"},
{"offense_team": 20460, "play": "Palensky,B walked; Rogers,B advanced to second.", "pitcher": "213098", "name": "214326", "pa_result": "BB"},
{"offense_team": 20460, "play": "Caniglia,A to c for Scribner,J.", "pitcher": "213098", "name": "194755"},
{"offense_team": 20460, "play": "Caniglia,A walked; Palensky,B advanced to second; Rogers,B advanced to third.", "pitcher": "213098", "name": "194755", "pa_result": "BB"},
{"offense_team": 20460, "play": "Smejkal,P grounded into double play ss to 2b to 1b; Caniglia,A out on the play; Palensky,B advanced to third; Rogers,B scored.", "pitcher": "213098", "name": "205310", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Dunn, D. singled to shortstop; Claeys advanced to third.", "pitcher": "202876", "name": "213094", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Maxwell hit by pitch; Dunn, D. advanced to second.", "pitcher": "202876", "name": "207874", "pa_result": "HBP"},
{"offense_team": 20037, "play": "Kelly walked, RBI; Maxwell advanced to second; Dunn, D. advanced to third; Claeys scored.", "pitcher": "214331", "name": "213097", "pa_result": "BB"},
{"offense_team": 20037, "play": "Bourbon grounded out to ss, RBI; Kelly advanced to second; Maxwell advanced to third; Dunn, D. scored.", "pitcher": "214331", "name": "213099", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Dickey struck out swinging.", "pitcher": "214331", "name": "201091", "pa_result": "K"},
{"offense_team": 20460, "play": "Krumwiede,K flied out to cf.", "pitcher": "213096", "name": "214336", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Lind doubled down the lf line.", "pitcher": "207634", "name": "195052", "pa_result": "2B", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Bourbon grounded out to 2b.", "pitcher": "207634", "name": "213099", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Dunn, D. singled up the middle, out at second cf to c to ss, RBI; Lind scored.", "pitcher": "207634", "name": "213094", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Kelly walked.", "pitcher": "207634", "name": "213097", "pa_result": "BB"},
{"offense_team": 20037, "play": "Maxwell struck out swinging (0-2 KKS).", "pitcher": "200400", "name": "207874", "pa_result": "K"},
{"offense_team": 20037, "play": "Kelly grounded out to 2b (3-2 BBFBF).", "pitcher": "200400", "name": "213097", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20454, "play": "Cosentino popped up to 2b (2-0 BB).", "pitcher": "213095", "name": "206843", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20454, "play": "Groshans, J. walked (3-2 FFBBFBB).", "pitcher": "213095", "name": "204752", "pa_result": "BB"},
{"offense_team": 20454, "play": "Groshans, J. advanced to second on a balk.", "pitcher": "213095", "name": "204752"},
{"offense_team": 20460, "play": "Daugherty,T grounded out to ss.", "pitcher": "213098", "name": "214333", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Lind flied out to cf.", "pitcher": "214330", "name": "195052", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dunn, D. grounded out to 3b, bunt.", "pitcher": "214330", "name": "213094", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Bourbon grounded out to 2b.", "pitcher": "214330", "name": "213099", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Gamm,M reached on a throwing error by 2b, advanced to second.", "pitcher": "213098", "name": "214328", "pa_result": "E/FC", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Thibodeau,C struck out swinging.", "pitcher": "213098", "name": "205739", "pa_result": "K"},
{"offense_team": 20460, "play": "Suponchick,G to dh for Hughes,H.", "pitcher": "213098", "name": "202876"},
{"offense_team": 20460, "play": "Suponchick,G singled up the middle, RBI; Gamm,M scored, unearned.", "pitcher": "213098", "name": "202876", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20460, "play": "Krumwiede,K flied out to cf.", "pitcher": "213098", "name": "214336", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20460, "play": "Caniglia,A walked.", "pitcher": "206118", "name": "194755", "pa_result": "BB"},
{"offense_team": 20460, "play": "Smejkal,P singled to right field; Caniglia,A advanced to second.", "pitcher": "206118", "name": "205310", "pa_result": "1B", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Daugherty,T singled to third base, bunt; Smejkal,P advanced to second; Caniglia,A advanced to third.", "pitcher": "206118", "name": "214333", "pa_result": "1B", "batted_ball_location": "3B"},
{"offense_team": 20460, "play": "Gamm,M singled through the left side, RBI; Daugherty,T advanced to second; Smejkal,P advanced to third; Caniglia,A scored.", "pitcher": "206118", "name": "214328", "pa_result": "1B", "batted_ball_location": "LS"},
{"offense_team": 20460, "play": "Thibodeau,C singled to center field, RBI; Gamm,M advanced to second; Daugherty,T advanced to third; Smejkal,P scored.", "pitcher": "206118", "name": "205739", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20460, "play": "Hughes,H walked, RBI; Thibodeau,C advanced to second; Gamm,M advanced to third; Daugherty,T scored.", "pitcher": "201093", "name": "214337", "pa_result": "BB"},
{"offense_team": 20460, "play": "Krumwiede,K reached on a fielder's choice, RBI; Hughes,H out at second 3b to 2b; Thibodeau,C advanced to third; Gamm,M scored.", "pitcher": "201093", "name": "214336", "pa_result": "E/FC", "batted_ball_location": "3B"},
{"offense_team": 20460, "play": "Rogers,B walked; Krumwiede,K advanced to second.", "pitcher": "201093", "name": "214327", "pa_result": "BB"},
{"offense_team": 20460, "play": "Palensky,B singled to center field, RBI; Rogers,B advanced to second; Krumwiede,K advanced to third; Thibodeau,C scored.", "pitcher": "201093", "name": "214326", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20460, "play": "Caniglia,A singled to left field, RBI; Palensky,B advanced to second; Rogers,B advanced to third; Krumwiede,K scored.", "pitcher": "201093", "name": "194755", "pa_result": "1B", "batted_ball_location": "LF"},
{"offense_team": 20460, "play": "Smejkal,P popped up to rf.", "pitcher": "201093", "name": "205310", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20460, "play": "Daugherty,T flied out to cf.", "pitcher": "201093", "name": "214333", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dunn, J. struck out looking.", "pitcher": "214331", "name": "201089", "pa_result": "K"},
{"offense_team": 20454, "play": "Citta, B. struck out swinging (3-2 BSBSBFFS).", "pitcher": "213095", "name": "201464", "pa_result": "K"},
{"offense_team": 20454, "play": "Groshans, J. advanced to third on a passed ball.", "pitcher": "195053", "name": "204752"},
{"offense_team": 20454, "play": "Foyle, D. singled to third base, RBI (3-2 BBBSS); Groshans, J. scored.", "pitcher": "195053", "name": "200402", "pa_result": "1B", "batted_ball_location": "3B"},
{"offense_team": 20454, "play": "Vosik, B. pinch hit.", "pitcher": "195053", "name": "206533"},
{"offense_team": 20454, "play": "Foyle, D. stole second.", "pitcher": "195053", "name": "200402", "pa_result": "SB"},
{"offense_team": 20454, "play": "Vosik, B. walked (3-2 BBKFBB).", "pitcher": "195053", "name": "206533", "pa_result": "BB"},
{"offense_team": 20454, "play": "Taylor, O. walked (3-0 BBBB); Vosik, B. advanced to second; Foyle, D. advanced to third.", "pitcher": "195053", "name": "188251", "pa_result": "BB"},
{"offense_team": 20454, "play": "Messinger, S flied out to cf (0-0).", "pitcher": "195053", "name": "210030", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dickey singled up the middle (0-1 K).", "pitcher": "200400", "name": "201091", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Dickey advanced to second on a wild pitch.", "pitcher": "200400", "name": "201091"},
{"offense_team": 20037, "play": "Dunn, J. fouled out to 1b (3-2 BBKFB).", "pitcher": "200400", "name": "201089"},
{"offense_team": 20037, "play": "Erro singled to second base, advanced to second on a throwing error by 2b (1-1 BK); Dickey scored on the error.", "pitcher": "200400", "name": "205672", "pa_result": "1B", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Rogers,B reached on a fielder's choice; Suponchick,G out at second ss to 2b.", "pitcher": "213098", "name": "214327", "pa_result": "E/FC", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Kelly lined out to 2b.", "pitcher": "214330", "name": "213097", "pa_result": "L", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "O'Laughlin tripled to right center.", "pitcher": "214330", "name": "213101", "pa_result": "3B", "batted_ball_location": "RC"},
{"offense_team": 20037, "play": "Dickey struck out swinging.", "pitcher": "214330", "name": "201091", "pa_result": "K"},
{"offense_team": 20037, "play": "Dunn, J. grounded out to ss.", "pitcher": "214330", "name": "201089", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20460, "play": "Palensky,B popped up to 2b.", "pitcher": "213098", "name": "214326", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Erro walked.", "pitcher": "214331", "name": "205672", "pa_result": "BB"},
{"offense_team": 20037, "play": "Claeys struck out looking.", "pitcher": "214331", "name": "195056", "pa_result": "K"},
{"offense_team": 20037, "play": "Erro stole second.", "pitcher": "214331", "name": "205672", "pa_result": "SB"},
{"offense_team": 20037, "play": "Erro stole third.", "pitcher": "214331", "name": "205672", "pa_result": "SB"},
{"offense_team": 20037, "play": "Lind struck out swinging.", "pitcher": "214331", "name": "195052", "pa_result": "K"},
{"offense_team": 20460, "play": "Gamm,M lined out to cf.", "pitcher": "201093", "name": "214328", "pa_result": "L", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Bourbon singled to center field, RBI (1-1 KB); Erro scored.", "pitcher": "200400", "name": "213099", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Lind walked (3-0 BBBB); Bourbon advanced to second.", "pitcher": "200799", "name": "195052", "pa_result": "BB"},
{"offense_team": 20037, "play": "Dunn, D. flied out to rf (1-1 BK).", "pitcher": "200799", "name": "213094", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Caniglia,A grounded out to ss.", "pitcher": "213098", "name": "194755", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20460, "play": "Smejkal,P doubled down the rf line.", "pitcher": "213098", "name": "205310", "pa_result": "2B", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Daugherty,T singled to right field, advanced to second on the throw, RBI; Smejkal,P scored.", "pitcher": "195053", "name": "214333", "pa_result": "1B", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Gamm,M walked.", "pitcher": "195053", "name": "214328", "pa_result": "BB"},
{"offense_team": 20460, "play": "Thibodeau,C walked; Gamm,M advanced to second; Daugherty,T advanced to third.", "pitcher": "195053", "name": "205739", "pa_result": "BB"},
{"offense_team": 20460, "play": "Suponchick,G singled to right field, 2 RBI; Thibodeau,C advanced to third; Gamm,M scored; Daugherty,T scored.", "pitcher": "195053", "name": "202876", "pa_result": "1B", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Krumwiede,K grounded out to 2b.", "pitcher": "195053", "name": "214336", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Erro flied out to lf.", "pitcher": "214330", "name": "205672", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Claeys walked.", "pitcher": "214330", "name": "195056", "pa_result": "BB"},
{"offense_team": 20183, "play": "Thomas popped up to 2b.", "pitcher": "213095", "name": "200727", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20460, "play": "Thibodeau,C walked.", "pitcher": "201093", "name": "205739", "pa_result": "BB"},
{"offense_team": 20460, "play": "Hughes,H grounded into double play p to ss to 1b; Thibodeau,C out on the play.", "pitcher": "201093", "name": "214337", "pa_result": "G", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Dunn, D. tripled to right center.", "pitcher": "214331", "name": "213094", "pa_result": "3B", "batted_ball_location": "RC"},
{"offense_team": 20037, "play": "O'Laughlin singled through the right side, RBI; Dunn, D. scored.", "pitcher": "214331", "name": "213101", "pa_result": "1B", "batted_ball_location": "RS"},
{"offense_team": 20037, "play": "Kelly lined out to rf.", "pitcher": "214331", "name": "213097", "pa_result": "L", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Bourbon struck out swinging.", "pitcher": "214331", "name": "213099", "pa_result": "K"},
{"offense_team": 20037, "play": "Dickey doubled down the rf line; O'Laughlin advanced to third.", "pitcher": "214331", "name": "201091", "pa_result": "2B", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Dunn, J. singled to left field, 2 RBI; Dickey scored; O'Laughlin scored.", "pitcher": "214331", "name": "201089", "pa_result": "1B", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Dunn, J. stole second.", "pitcher": "214331", "name": "201089", "pa_result": "SB"},
{"offense_team": 20037, "play": "Erro reached on a throwing error by ss; Dunn, J. advanced to third.", "pitcher": "214331", "name": "205672", "pa_result": "E/FC", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Kaplan flied out to rf (0-1 K).", "pitcher": "200799", "name": "204249", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20454, "play": "Sems, B. popped up to 2b (0-1 S).", "pitcher": "201093", "name": "205446", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20454, "play": "Ray, B. walked (3-0 BBBB).", "pitcher": "201093", "name": "215108", "pa_result": "BB"},
{"offense_team": 20454, "play": "Cosentino reached on a fielder's choice (0-1 K); Ray, B. out at second 1b to ss.", "pitcher": "201093", "name": "206843", "pa_result": "E/FC", "batted_ball_location": "1B"},
{"offense_team": 20037, "play": "Lind struck out swinging.", "pitcher": "214330", "name": "195052", "pa_result": "K"},
{"offense_team": 20037, "play": "Dunn, D. grounded out to 2b.", "pitcher": "214330", "name": "213094", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Rogers,B singled through the left side.", "pitcher": "206186", "name": "214327", "pa_result": "1B", "batted_ball_location": "LS"},
{"offense_team": 20460, "play": "Rogers,B advanced to second on a wild pitch.", "pitcher": "206186", "name": "214327"},
{"offense_team": 20460, "play": "Palensky,B hit by pitch.", "pitcher": "206186", "name": "214326", "pa_result": "HBP"},
{"offense_team": 20460, "play": "Caniglia,A grounded out to p, SAC; Palensky,B advanced to second; Rogers,B advanced to third.", "pitcher": "206186", "name": "194755", "pa_result": "G", "batted_ball_location": "P"},
{"offense_team": 20460, "play": "Smejkal,P singled to center field, RBI; Palensky,B advanced to third; Rogers,B scored.", "pitcher": "206186", "name": "205310", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20183, "play": "Bullock struck out looking.", "pitcher": "213095", "name": "208070", "pa_result": "K"},
{"offense_team": 20183, "play": "Engelmann singled up the middle.", "pitcher": "213095", "name": "197482", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20183, "play": "Nelson singled up the middle; Engelmann advanced to second.", "pitcher": "213095", "name": "211948", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20183, "play": "Franklin grounded out to ss.", "pitcher": "213095", "name": "210213", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Dunn, J. struck out looking.", "pitcher": "207061", "name": "201089", "pa_result": "K"},
{"offense_team": 20037, "play": "Erro popped up to 2b.", "pitcher": "207061", "name": "205672", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Claeys struck out looking.", "pitcher": "207061", "name": "195056", "pa_result": "K"},
{"offense_team": 20183, "play": "Nwogu grounded out to 2b.", "pitcher": "213095", "name": "211955", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20183, "play": "Clementi grounded out to 1b unassisted.", "pitcher": "213095", "name": "205380", "pa_result": "G", "batted_ball_location": "1B"},
{"offense_team": 20183, "play": "Keener popped up to 1b.", "pitcher": "213095", "name": "206551", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Jones to c for Claeys.", "pitcher": "214331", "name": "201097"},
{"offense_team": 20037, "play": "Dunn, J. scored on the throw, unearned.", "pitcher": "214331", "name": "201089"},
{"offense_team": 20037, "play": "Jones walked; Erro advanced to second.", "pitcher": "214331", "name": "201097", "pa_result": "BB"},
{"offense_team": 20037, "play": "Lind struck out swinging.", "pitcher": "214331", "name": "195052", "pa_result": "K"},
{"offense_team": 20460, "play": "Krumwiede,K singled to center field.", "pitcher": "201093", "name": "214336", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20454, "play": "Cosentino stole second.", "pitcher": "201093", "name": "206843", "pa_result": "SB"},
{"offense_team": 20454, "play": "Groshans, J. flied out to lf (2-1 BKB).", "pitcher": "201093", "name": "204752", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Maxwell flied out to cf (1-1 KB).", "pitcher": "200799", "name": "207874", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Kelly walked (3-2 KBBFBB).", "pitcher": "200799", "name": "213097", "pa_result": "BB"},
{"offense_team": 20037, "play": "Dickey walked (3-2 BBKBKB); Kelly advanced to second.", "pitcher": "200799", "name": "201091", "pa_result": "BB"},
{"offense_team": 20037, "play": "Dunn, J. flied out to rf (0-0).", "pitcher": "200799", "name": "201089", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Erro grounded out to 2b (2-1 BKB).", "pitcher": "200799", "name": "205672", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20454, "play": "Citta, B. struck out looking (2-2 BFBSK).", "pitcher": "201093", "name": "201464", "pa_result": "K"},
{"offense_team": 20454, "play": "Foyle, D. singled through the right side (0-1 K).", "pitcher": "201093", "name": "200402", "pa_result": "1B", "batted_ball_location": "RS"},
{"offense_team": 20454, "play": "Vosik, B. to dh.", "pitcher": "201093", "name": "206533"},
{"offense_team": 20454, "play": "Vosik, B. struck out looking (3-2 KFBBBK).", "pitcher": "195057", "name": "206533", "pa_result": "K"},
{"offense_team": 20454, "play": "Foyle, D. stole second.", "pitcher": "195057", "name": "200402", "pa_result": "SB"},
{"offense_team": 20454, "play": "Taylor, O. struck out swinging (1-2 BFKS).", "pitcher": "195057", "name": "188251", "pa_result": "K"},
{"offense_team": 20037, "play": "Bourbon grounded out to ss (2-2 KKBFB).", "pitcher": "200799", "name": "213099", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Lind singled to shortstop (2-1 BBK).", "pitcher": "200799", "name": "195052", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Dunn, D. struck out swinging (0-2 KKS).", "pitcher": "200799", "name": "213094", "pa_result": "K"},
{"offense_team": 20037, "play": "O'Laughlin pinch hit for Kaplan.", "pitcher": "200799", "name": "213101"},
{"offense_team": 20037, "play": "O'Laughlin flied out to cf (0-0).", "pitcher": "200799", "name": "213101", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20460, "play": "Daugherty,T flied out to rf, SF, RBI; Palensky,B scored.", "pitcher": "206186", "name": "214333", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20460, "play": "Gamm,M grounded out to 3b.", "pitcher": "206186", "name": "214328", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Bourbon flied out to lf.", "pitcher": "214330", "name": "213099", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Kelly struck out looking.", "pitcher": "214330", "name": "213097", "pa_result": "K"},
{"offense_team": 20037, "play": "O'Laughlin struck out swinging.", "pitcher": "214330", "name": "213101", "pa_result": "K"},
{"offense_team": 20183, "play": "Thomas flied out to cf.", "pitcher": "205826", "name": "200727", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20183, "play": "Thomas walked.", "pitcher": "213096", "name": "200727", "pa_result": "BB"},
{"offense_team": 20037, "play": "Bourbon struck out swinging.", "pitcher": "207061", "name": "213099", "pa_result": "K"},
{"offense_team": 20037, "play": "Lind flied out to cf.", "pitcher": "207061", "name": "195052", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dickey walked.", "pitcher": "207061", "name": "201091", "pa_result": "BB"},
{"offense_team": 20037, "play": "Maxwell struck out looking.", "pitcher": "207061", "name": "207874", "pa_result": "K"},
{"offense_team": 20183, "play": "Blomgren singled to left center.", "pitcher": "213095", "name": "211949", "pa_result": "1B", "batted_ball_location": "LC"},
{"offense_team": 20183, "play": "Thomas flied out to rf.", "pitcher": "213095", "name": "200727", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20183, "play": "Bullock flied out to rf.", "pitcher": "213095", "name": "208070", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20183, "play": "Engelmann struck out swinging.", "pitcher": "213095", "name": "197482", "pa_result": "K"},
{"offense_team": 20037, "play": "Kaplan singled up the middle.", "pitcher": "207061", "name": "204249", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20460, "play": "Rogers,B grounded into double play 2b to ss to 1b; Krumwiede,K out on the play.", "pitcher": "201093", "name": "214327", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20460, "play": "Palensky,B flied out to rf.", "pitcher": "201093", "name": "214326", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Dunn, D. flied out to cf.", "pitcher": "214325", "name": "213094", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "O'Laughlin grounded out to ss.", "pitcher": "214325", "name": "213101", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Kelly grounded out to 2b.", "pitcher": "214325", "name": "213097", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20183, "play": "Bullock grounded out to ss.", "pitcher": "205826", "name": "208070", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20183, "play": "Engelmann flied out to cf.", "pitcher": "205826", "name": "197482", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dunn, J. grounded out to 3b.", "pitcher": "211950", "name": "201089", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Erro grounded out to 2b.", "pitcher": "211950", "name": "205672", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Claeys grounded out to ss.", "pitcher": "211950", "name": "195056", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20183, "play": "Franklin fouled out to 3b.", "pitcher": "205826", "name": "210213"},
{"offense_team": 20183, "play": "Nelson grounded out to 3b.", "pitcher": "205826", "name": "211948", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20183, "play": "Bullock struck out swinging; Thomas stole second.", "pitcher": "213096", "name": "208070", "pa_result": "K"},
{"offense_team": 20183, "play": "Engelmann struck out swinging.", "pitcher": "213096", "name": "197482", "pa_result": "K"},
{"offense_team": 20183, "play": "Nelson struck out swinging.", "pitcher": "213096", "name": "211948", "pa_result": "K"},
{"offense_team": 20037, "play": "Dunn, J. singled up the middle.", "pitcher": "204793", "name": "201089", "pa_result": "1B", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Erro grounded into double play 2b to ss to 1b; Dunn, J. out on the play.", "pitcher": "204793", "name": "205672", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Claeys grounded out to 3b.", "pitcher": "204793", "name": "195056", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20183, "play": "Nwogu struck out swinging.", "pitcher": "213096", "name": "211955", "pa_result": "K"},
{"offense_team": 20183, "play": "Franklin struck out looking.", "pitcher": "213096", "name": "210213", "pa_result": "K"},
{"offense_team": 20183, "play": "Lewis doubled to left center.", "pitcher": "213096", "name": "194953", "pa_result": "2B", "batted_ball_location": "LC"},
{"offense_team": 20183, "play": "Clementi grounded out to 2b.", "pitcher": "205826", "name": "205380", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Bourbon singled to left center.", "pitcher": "211950", "name": "213099", "pa_result": "1B", "batted_ball_location": "LC"},
{"offense_team": 20037, "play": "Lind grounded out to 1b unassisted; Bourbon advanced to second.", "pitcher": "211950", "name": "195052", "pa_result": "G", "batted_ball_location": "1B"},
{"offense_team": 20037, "play": "Dickey popped up to ss.", "pitcher": "211950", "name": "201091", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Kaplan flied out to rf.", "pitcher": "211950", "name": "204249", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20183, "play": "Nwogu doubled to left center.", "pitcher": "205826", "name": "211955", "pa_result": "2B", "batted_ball_location": "LC"},
{"offense_team": 20183, "play": "Salter grounded out to p, SAC, bunt; Nwogu advanced to third.", "pitcher": "205826", "name": "208085", "pa_result": "G", "batted_ball_location": "P"},
{"offense_team": 20183, "play": "Blomgren singled, RBI; Nwogu scored.", "pitcher": "205826", "name": "211949"},
{"offense_team": 20183, "play": "Thomas flied out to cf; Blomgren out at first rf to 1b.", "pitcher": "205826", "name": "200727", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20183, "play": "Keener grounded out to 3b.", "pitcher": "213096", "name": "206551", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Bourbon struck out swinging.", "pitcher": "204793", "name": "213099", "pa_result": "K"},
{"offense_team": 20037, "play": "Kaplan singled to left field.", "pitcher": "204793", "name": "204249", "pa_result": "1B", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Kaplan out at second c to ss, caught stealing.", "pitcher": "204793", "name": "204249"},
{"offense_team": 20037, "play": "Maxwell walked.", "pitcher": "204793", "name": "207874", "pa_result": "BB"},
{"offense_team": 20037, "play": "Maxwell advanced to second on a passed ball.", "pitcher": "204793", "name": "207874"},
{"offense_team": 20037, "play": "O'Laughlin grounded out to 2b.", "pitcher": "204793", "name": "213101", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20183, "play": "Blomgren walked.", "pitcher": "213096", "name": "211949", "pa_result": "BB"},
{"offense_team": 20183, "play": "Thomas grounded out to 1b unassisted; Blomgren advanced to second.", "pitcher": "213096", "name": "200727", "pa_result": "G", "batted_ball_location": "1B"},
{"offense_team": 20183, "play": "Bullock out at first p to 2b to 1b; Blomgren advanced to third.", "pitcher": "213096", "name": "208070"},
{"offense_team": 20183, "play": "Engelmann walked.", "pitcher": "213096", "name": "197482", "pa_result": "BB"},
{"offense_team": 20183, "play": "Engelmann stole second.", "pitcher": "213096", "name": "197482", "pa_result": "SB"},
{"offense_team": 20183, "play": "Nelson grounded out to 2b.", "pitcher": "213096", "name": "211948", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20179, "play": "Whelan struck out swinging.", "pitcher": "213095", "name": "192964", "pa_result": "K"},
{"offense_team": 20179, "play": "Wetrich struck out looking.", "pitcher": "213095", "name": "212655", "pa_result": "K"},
{"offense_team": 20179, "play": "Cropley flied out to cf.", "pitcher": "213095", "name": "205158", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dunn, J. grounded out to 1b unassisted.", "pitcher": "193950", "name": "201089", "pa_result": "G", "batted_ball_location": "1B"},
{"offense_team": 20037, "play": "Erro struck out swinging.", "pitcher": "193950", "name": "205672", "pa_result": "K"},
{"offense_team": 20037, "play": "Claeys walked.", "pitcher": "193950", "name": "195056", "pa_result": "BB"},
{"offense_team": 20037, "play": "Bourbon struck out swinging.", "pitcher": "193950", "name": "213099", "pa_result": "K"},
{"offense_team": 20179, "play": "Neustrom grounded out to ss.", "pitcher": "213095", "name": "200377", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20179, "play": "Hoeg singled to left field.", "pitcher": "213095", "name": "204825", "pa_result": "1B", "batted_ball_location": "LF"},
{"offense_team": 20179, "play": "Hoeg advanced to second on a passed ball.", "pitcher": "213095", "name": "204825"},
{"offense_team": 20179, "play": "Crowl singled to right field, RBI; Hoeg scored, unearned.", "pitcher": "213095", "name": "204800", "pa_result": "1B", "batted_ball_location": "RF"},
{"offense_team": 20179, "play": "Elion lined out to ss.", "pitcher": "213095", "name": "212652", "pa_result": "L", "batted_ball_location": "SS"},
{"offense_team": 20179, "play": "Jenkins flied out to lf.", "pitcher": "213095", "name": "207537", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Lind flied out to cf.", "pitcher": "193950", "name": "195052", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dickey flied out to rf.", "pitcher": "193950", "name": "201091", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Maxwell reached on a throwing error by 3b.", "pitcher": "193950", "name": "207874", "pa_result": "E/FC", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Kaplan singled to left center; Maxwell advanced to third.", "pitcher": "193950", "name": "204249", "pa_result": "1B", "batted_ball_location": "LC"},
{"offense_team": 20037, "play": "O'Laughlin grounded out to 2b.", "pitcher": "193950", "name": "213101", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20179, "play": "Boe singled to left field.", "pitcher": "213095", "name": "200368", "pa_result": "1B", "batted_ball_location": "LF"},
{"offense_team": 20179, "play": "Whelan grounded into double play ss to 2b to 1b; Boe out on the play.", "pitcher": "213095", "name": "192964", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20179, "play": "Wetrich flied out to cf.", "pitcher": "213095", "name": "212655", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dunn, J. popped up to cf.", "pitcher": "193950", "name": "201089", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Erro singled to left field.", "pitcher": "193950", "name": "205672", "pa_result": "1B", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Claeys lined out to 2b; Erro out at first 2b to 1b.", "pitcher": "193950", "name": "195056", "pa_result": "L", "batted_ball_location": "2B"},
{"offense_team": 20179, "play": "Cropley flied out to rf.", "pitcher": "213095", "name": "205158", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20179, "play": "Neustrom flied out to lf.", "pitcher": "213095", "name": "200377", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20179, "play": "Hoeg struck out swinging.", "pitcher": "213095", "name": "204825", "pa_result": "K"},
{"offense_team": 20037, "play": "Bourbon grounded out to ss.", "pitcher": "193950", "name": "213099", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Lind struck out looking.", "pitcher": "193950", "name": "195052", "pa_result": "K"},
{"offense_team": 20037, "play": "Dickey flied out to rf.", "pitcher": "193950", "name": "201091", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20179, "play": "Crowl flied out to rf.", "pitcher": "213095", "name": "204800", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20179, "play": "Elion grounded out to p, bunt.", "pitcher": "213095", "name": "212652", "pa_result": "G", "batted_ball_location": "P"},
{"offense_team": 20179, "play": "Jenkins grounded out to 2b.", "pitcher": "213095", "name": "207537", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Lind to 3b.", "pitcher": "193950", "name": "195052"},
{"offense_team": 20179, "play": "Whelan grounded out to 2b.", "pitcher": "205826", "name": "192964", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20179, "play": "Neustrom flied out to cf.", "pitcher": "205826", "name": "200377", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20179, "play": "Cropley lined out to 2b.", "pitcher": "205826", "name": "205158", "pa_result": "L", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Dunn, J. grounded out to 3b.", "pitcher": "204230", "name": "201089", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Erro lined out to cf.", "pitcher": "204230", "name": "205672", "pa_result": "L", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Claeys walked.", "pitcher": "204230", "name": "195056", "pa_result": "BB"},
{"offense_team": 20179, "play": "Whelan flied out to lf.", "pitcher": "206118", "name": "192964", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Bourbon singled to pitcher; Claeys advanced to second.", "pitcher": "204230", "name": "213099"},
{"offense_team": 20037, "play": "Lind singled to right field, 2 RBI; Bourbon scored; Claeys scored.", "pitcher": "204230", "name": "195052", "pa_result": "1B", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Maxwell struck out swinging.", "pitcher": "204230", "name": "207874", "pa_result": "K"},
{"offense_team": 20179, "play": "Guzzo struck out swinging.", "pitcher": "205826", "name": "193947", "pa_result": "K"},
{"offense_team": 20179, "play": "Hoeg singled to third base.", "pitcher": "205826", "name": "204825", "pa_result": "1B", "batted_ball_location": "3B"},
{"offense_team": 20179, "play": "Crowl flied out to lf.", "pitcher": "205826", "name": "204800", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20179, "play": "Elion flied out to cf.", "pitcher": "205826", "name": "212652", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Dickey lined out to cf.", "pitcher": "204230", "name": "201091", "pa_result": "L", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Kaplan struck out swinging.", "pitcher": "204230", "name": "204249", "pa_result": "K"},
{"offense_team": 20037, "play": "O'Laughlin grounded out to 2b.", "pitcher": "204230", "name": "213101", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20179, "play": "Jenkins flied out to rf.", "pitcher": "205826", "name": "207537", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20179, "play": "Boe singled to center field.", "pitcher": "205826", "name": "200368", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20179, "play": "Boe stole second.", "pitcher": "205826", "name": "200368", "pa_result": "SB"},
{"offense_team": 20179, "play": "Whelan flied out to rf; Boe advanced to third.", "pitcher": "205826", "name": "192964", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20179, "play": "Neustrom grounded out to 1b unassisted.", "pitcher": "205826", "name": "200377", "pa_result": "G", "batted_ball_location": "1B"},
{"offense_team": 20037, "play": "Dunn, J. walked.", "pitcher": "204230", "name": "201089", "pa_result": "BB"},
{"offense_team": 20179, "play": "Crowl grounded out to 3b.", "pitcher": "206118", "name": "204800", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20179, "play": "Cropley singled to center field.", "pitcher": "206118", "name": "205158", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20179, "play": "Neustrom struck out looking.", "pitcher": "206118", "name": "200377", "pa_result": "K"},
{"offense_team": 20037, "play": "Dunn, J. flied out to rf.", "pitcher": "212661", "name": "201089", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Erro flied out to rf.", "pitcher": "212661", "name": "205672", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Claeys struck out swinging.", "pitcher": "212661", "name": "195056", "pa_result": "K"},
{"offense_team": 20179, "play": "Hoeg walked.", "pitcher": "206118", "name": "204825", "pa_result": "BB"},
{"offense_team": 20179, "play": "Elion flied out to rf.", "pitcher": "206118", "name": "212652", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20179, "play": "Jenkins struck out swinging.", "pitcher": "206118", "name": "207537", "pa_result": "K"},
{"offense_team": 20179, "play": "Hoeg stole second.", "pitcher": "206118", "name": "204825", "pa_result": "SB"},
{"offense_team": 20037, "play": "Erro singled to left field; Dunn, J. advanced to second.", "pitcher": "204230", "name": "205672", "pa_result": "1B", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Claeys popped up to 1b.", "pitcher": "204230", "name": "195056", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20037, "play": "Bourbon flied out to lf.", "pitcher": "204230", "name": "213099", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Lind singled to left field, RBI; Erro advanced to second; Dunn, J. scored.", "pitcher": "206754", "name": "195052", "pa_result": "1B", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Erro stole third.", "pitcher": "206754", "name": "205672", "pa_result": "SB"},
{"offense_team": 20037, "play": "Maxwell flied out to cf.", "pitcher": "206754", "name": "207874", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20179, "play": "Cropley flied out to lf.", "pitcher": "205826", "name": "205158", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20179, "play": "Guzzo struck out swinging.", "pitcher": "205826", "name": "193947", "pa_result": "K"},
{"offense_team": 20179, "play": "Hoeg singled to left field.", "pitcher": "205826", "name": "204825", "pa_result": "1B", "batted_ball_location": "LF"},
{"offense_team": 20179, "play": "Crowl reached on a fielder's choice; Hoeg out at second 3b to 2b.", "pitcher": "205826", "name": "204800", "pa_result": "E/FC", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Dickey flied out to rf.", "pitcher": "206754", "name": "201091", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Kaplan struck out swinging.", "pitcher": "206754", "name": "204249", "pa_result": "K"},
{"offense_team": 20037, "play": "O'Laughlin struck out swinging, out at first c to 1b.", "pitcher": "206754", "name": "213101", "pa_result": "K"},
{"offense_team": 20179, "play": "Elion flied out to rf.", "pitcher": "205826", "name": "212652", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20179, "play": "Jenkins grounded out to 3b.", "pitcher": "205826", "name": "207537", "pa_result": "G", "batted_ball_location": "3B"},
{"offense_team": 20179, "play": "Boe walked.", "pitcher": "205826", "name": "200368", "pa_result": "BB"},
{"offense_team": 20179, "play": "Boe out at second 2b to c, caught stealing.", "pitcher": "205826", "name": "200368"},
{"offense_team": 20037, "play": "Dunn, J. singled to third base.", "pitcher": "206754", "name": "201089", "pa_result": "1B", "batted_ball_location": "3B"},
{"offense_team": 20037, "play": "Erro struck out swinging.", "pitcher": "206754", "name": "205672", "pa_result": "K"},
{"offense_team": 20037, "play": "Claeys flied out to lf.", "pitcher": "206754", "name": "195056", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Bourbon flied out to lf.", "pitcher": "206754", "name": "213099", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20179, "play": "Whelan flied out to cf.", "pitcher": "205826", "name": "192964", "pa_result": "F", "batted_ball_location": "CF"},
{"offense_team": 20179, "play": "Neustrom popped up to 3b.", "pitcher": "205826", "name": "200377", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20179, "play": "Cropley walked.", "pitcher": "205826", "name": "205158", "pa_result": "BB"},
{"offense_team": 20179, "play": "Guzzo grounded out to 2b.", "pitcher": "205826", "name": "193947", "pa_result": "G", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Lind singled to center field.", "pitcher": "206754", "name": "195052", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20037, "play": "Maxwell doubled; Lind advanced to third.", "pitcher": "206754", "name": "207874"},
{"offense_team": 20037, "play": "Dickey walked.", "pitcher": "206754", "name": "201091", "pa_result": "BB"},
{"offense_team": 20037, "play": "Kaplan flied out to rf, SF, RBI; Maxwell advanced to third; Lind scored.", "pitcher": "204859", "name": "204249", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "O'Laughlin grounded into double play ss to 2b to 1b; Dickey out on the play.", "pitcher": "204859", "name": "213101", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20179, "play": "Hoeg popped up to 1b.", "pitcher": "205826", "name": "204825", "pa_result": "F", "batted_ball_location": "P"},
{"offense_team": 20179, "play": "Crowl flied out to lf.", "pitcher": "205826", "name": "204800", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20179, "play": "Elion singled to center field.", "pitcher": "205826", "name": "212652", "pa_result": "1B", "batted_ball_location": "CF"},
{"offense_team": 20179, "play": "Jenkins flied out to lf.", "pitcher": "205826", "name": "207537", "pa_result": "F", "batted_ball_location": "LF"},
{"offense_team": 20037, "play": "Dunn, J. reached on an error by ss.", "pitcher": "204859", "name": "201089", "pa_result": "E/FC", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Erro reached on a fielder's choice; Dunn, J. out at second 2b to ss.", "pitcher": "204859", "name": "205672", "pa_result": "E/FC", "batted_ball_location": "2B"},
{"offense_team": 20037, "play": "Claeys struck out swinging.", "pitcher": "204859", "name": "195056", "pa_result": "K"},
{"offense_team": 20037, "play": "Bourbon grounded out to ss.", "pitcher": "204859", "name": "213099", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20179, "play": "Boe walked.", "pitcher": "195057", "name": "200368", "pa_result": "BB"},
{"offense_team": 20179, "play": "Whelan lined out to 3b.", "pitcher": "195057", "name": "192964", "pa_result": "L", "batted_ball_location": "3B"},
{"offense_team": 20179, "play": "Neustrom reached on a fielder's choice; Boe out at second 2b to ss.", "pitcher": "195057", "name": "200377", "pa_result": "E/FC", "batted_ball_location": "2B"},
{"offense_team": 20179, "play": "Cropley flied out to rf.", "pitcher": "195057", "name": "205158", "pa_result": "F", "batted_ball_location": "RF"},
{"offense_team": 20037, "play": "Lind grounded out to ss.", "pitcher": "204859", "name": "195052", "pa_result": "G", "batted_ball_location": "SS"},
{"offense_team": 20037, "play": "Maxwell struck out looking.", "pitcher": "204859", "name": "207874", "pa_result": "K"},
{"offense_team": 20037, "play": "Dickey struck out swinging.", "pitcher": "204859", "name": "201091", "pa_result": "K"},
{"offense_team": 20179, "play": "Wetrich pinch hit for Guzzo.", "pitcher": "195057", "name": "212655"},
{"offense_team": 20179, "play": "Wetrich struck out looking.", "pitcher": "195057", "name": "212655", "pa_result": "K"},
{"offense_team": 20179, "play": "Hoeg struck out looking.", "pitcher": "195057", "name": "204825", "pa_result": "K"},
{"offense_team": 20179, "play": "Crowl grounded out to 2b.", "pitcher": "195057", "name": "204800", "pa_result": "G", "batted_ball_location": "2B"}
])
# Out:
#     batted_ball_location    name  offense_team pa_result pitcher  \
# 0                     CF  205739         20460        1B  205826
# 1                    NaN  205739         20460        SB  205826
# 2                    NaN  214337         20460         K  205826
# 3                     SS  214336         20460         G  205826
# 4                      P  214327         20460         G  205826
# 5                      P  201091         20037         G  202876
# 6                     3B  201089         20037        1B  202876
# 7                     RC  205672         20037        1B  202876
# 8                    NaN  205672         20037        SB  202876
# 9                    NaN  195056         20037         K  202876
# 10                   NaN  195052         20037         K  202876
# 11                   NaN  214326         20460         K  205826
# 12                   NaN  201091         20037         K  205328
# ...
